# %%
                              project

# %%
Q1. What is Multithreading in Python?
✅ Multithreading:

Multithreading ek process ke multiple threads ek saath execute karne ka concept hai.

Thread ek lightweight sub-process hota hai.

✅ Why used?

CPU-bound ya I/O-bound tasks ko efficiently run karne ke liye.

Program ko faster aur responsive banane ke liye.

✅ Module used:

# %%
import threading

# %%
Q2. Why threading module used?

threading module Python me threads create aur manage karne ke liye use hota hai.

✅ Functions:

activeCount() → Returns number of currently active threads

import threading
print(threading.activeCount())


currentThread() → Returns reference to the current thread

print(threading.currentThread())


enumerate() → Returns list of all active Thread objects

print(threading.enumerate())

Q3. Explain the following Thread functions

run() → Thread ka code define karta hai, normally thread start hone par run hota hai.

start() → Thread ko start kar

Q6. Explain Deadlocks and Race Conditions
✅ Deadlock:

Jab do ya zyada threads ek dusre ke resources ka wait karte hain aur kabhi release nahi hota.

Result → program hang ho jata hai.

✅ Race Condition:

Jab multiple threads shared resource ko simultaneously access karte hain.

Result → unpredictable output ya data corruption

Example of Race Condition:
import threading

counter = 0

def increment():
    global counter
    for _ in range(1000):
        counter += 1

t1 = threading.Thread(target=increment)
t2 = threading.Thread(target=increment)

t1.start()
t2.start()
t1.join()
t2.join()

print(counter)  # Output may vary due to race condition
